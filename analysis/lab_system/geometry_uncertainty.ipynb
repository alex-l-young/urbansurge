# %% [markdown]
# ## Add geometric uncertainty to stormwater system components.

# %%
# Library imports.
from pyswmm import Simulation, Links, Output
from swmm.toolkit.shared_enum import LinkAttribute, NodeAttribute, SubcatchAttribute
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import numpy.random as nprnd
from scipy.interpolate import griddata
from sklearn.linear_model import LinearRegression
import time

# Local imports.
from urbansurge import swmm_model, analysis_tools, file_utils

# %% [markdown]
# ### Load model.

# %%
# Configuration path.
config_path = r"C:\Users\ay434\Documents\urbansurge\analysis\lab_system\lab_system_physical_config.yml"

# Create instance of SWMM model.
swmm = swmm_model.SWMM(config_path)

# Configure model.
swmm.configure_model()
# Out:
# Simulation info
# Flow Units: CFS
# System Units: US
# Start Time: 2020-01-01 00:00:00
# Start Time: 2020-01-01 23:00:00

# %% [markdown]
# ### Add uncertainty to conduit diameters.

# %%
# Get names of conduits.
conduit_names = swmm.get_component_names('CONDUITS')

# Add uncertainty to conduit geometries.
conduit_bounds = (1, 1.5)

for conduit_name in conduit_names:
    # Get link geometry.
    geom = swmm.get_link_geometry(conduit_name)
    
    # Alter geometry with randomized value.
    new_diam = np.random.uniform(conduit_bounds[0], conduit_bounds[1])
    geom[0] = new_diam
    
    # Set new geometry.
    swmm.set_link_geometry(conduit_name, geom)
# Out:
# Updated Geom1 value to 1.0275907999214309 for 20 in 20
# Updated Geom2 value to 0.0 for 20 in 20
# Updated Geom3 value to 0.0 for 20 in 20
# Updated Geom4 value to 0.0 for 20 in 20
# Set Link 20 geometry to [1.0275907999214309, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.226580461169816 for 21 in 21
# Updated Geom2 value to 0.0 for 21 in 21
# Updated Geom3 value to 0.0 for 21 in 21
# Updated Geom4 value to 0.0 for 21 in 21
# Set Link 21 geometry to [1.226580461169816, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.2192257634522001 for 22 in 22
# Updated Geom2 value to 0.0 for 22 in 22
# Updated Geom3 value to 0.0 for 22 in 22
# Updated Geom4 value to 0.0 for 22 in 22
# Set Link 22 geometry to [1.2192257634522001, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.4432782246904754 for 23 in 23
# Updated Geom2 value to 0.0 for 23 in 23
# Updated Geom3 value to 0.0 for 23 in 23
# Updated Geom4 value to 0.0 for 23 in 23
# Set Link 23 geometry to [1.4432782246904754, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0661304945297068 for 24 in 24
# Updated Geom2 value to 0.0 for 24 in 24
# Updated Geom3 value to 0.0 for 24 in 24
# Updated Geom4 value to 0.0 for 24 in 24
# Set Link 24 geometry to [1.0661304945297068, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0212949011015935 for 25 in 25
# Updated Geom2 value to 0.0 for 25 in 25
# Updated Geom3 value to 0.0 for 25 in 25
# Updated Geom4 value to 0.0 for 25 in 25
# Set Link 25 geometry to [1.0212949011015935, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.4951319619617203 for 26 in 26
# Updated Geom2 value to 0.0 for 26 in 26
# Updated Geom3 value to 0.0 for 26 in 26
# Updated Geom4 value to 0.0 for 26 in 26
# Set Link 26 geometry to [1.4951319619617203, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.4666859639300227 for 27 in 27
# Updated Geom2 value to 0.0 for 27 in 27
# Updated Geom3 value to 0.0 for 27 in 27
# Updated Geom4 value to 0.0 for 27 in 27
# Set Link 27 geometry to [1.4666859639300227, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1861833967278832 for 28 in 28
# Updated Geom2 value to 0.0 for 28 in 28
# Updated Geom3 value to 0.0 for 28 in 28
# Updated Geom4 value to 0.0 for 28 in 28
# Set Link 28 geometry to [1.1861833967278832, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0595003750387395 for 29 in 29
# Updated Geom2 value to 0.0 for 29 in 29
# Updated Geom3 value to 0.0 for 29 in 29
# Updated Geom4 value to 0.0 for 29 in 29
# Set Link 29 geometry to [1.0595003750387395, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0730940337238135 for 33 in 33
# Updated Geom2 value to 0.0 for 33 in 33
# Updated Geom3 value to 0.0 for 33 in 33
# Updated Geom4 value to 0.0 for 33 in 33
# Set Link 33 geometry to [1.0730940337238135, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.3288911317224692 for 34 in 34
# Updated Geom2 value to 0.0 for 34 in 34
# Updated Geom3 value to 0.0 for 34 in 34
# Updated Geom4 value to 0.0 for 34 in 34
# Set Link 34 geometry to [1.3288911317224692, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.3951470884008734 for 37 in 37
# Updated Geom2 value to 0.0 for 37 in 37
# Updated Geom3 value to 0.0 for 37 in 37
# Updated Geom4 value to 0.0 for 37 in 37
# Set Link 37 geometry to [1.3951470884008734, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1671344798842593 for 38 in 38
# Updated Geom2 value to 0.0 for 38 in 38
# Updated Geom3 value to 0.0 for 38 in 38
# Updated Geom4 value to 0.0 for 38 in 38
# Set Link 38 geometry to [1.1671344798842593, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0028531537747964 for 39 in 39
# Updated Geom2 value to 0.0 for 39 in 39
# Updated Geom3 value to 0.0 for 39 in 39
# Updated Geom4 value to 0.0 for 39 in 39
# Set Link 39 geometry to [1.0028531537747964, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1166103091032937 for 40 in 40
# Updated Geom2 value to 0.0 for 40 in 40
# Updated Geom3 value to 0.0 for 40 in 40
# Updated Geom4 value to 0.0 for 40 in 40
# Set Link 40 geometry to [1.1166103091032937, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1396167701770386 for 41 in 41
# Updated Geom2 value to 0.0 for 41 in 41
# Updated Geom3 value to 0.0 for 41 in 41
# Updated Geom4 value to 0.0 for 41 in 41
# Set Link 41 geometry to [1.1396167701770386, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1662874713534437 for 42 in 42
# Updated Geom2 value to 0.0 for 42 in 42
# Updated Geom3 value to 0.0 for 42 in 42
# Updated Geom4 value to 0.0 for 42 in 42
# Set Link 42 geometry to [1.1662874713534437, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0602089217153803 for 43 in 43
# Updated Geom2 value to 0.0 for 43 in 43
# Updated Geom3 value to 0.0 for 43 in 43
# Updated Geom4 value to 0.0 for 43 in 43
# Set Link 43 geometry to [1.0602089217153803, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0059511598934021 for 44 in 44
# Updated Geom2 value to 0.0 for 44 in 44
# Updated Geom3 value to 0.0 for 44 in 44
# Updated Geom4 value to 0.0 for 44 in 44
# Set Link 44 geometry to [1.0059511598934021, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.2876667490722287 for 45 in 45
# Updated Geom2 value to 0.0 for 45 in 45
# Updated Geom3 value to 0.0 for 45 in 45
# Updated Geom4 value to 0.0 for 45 in 45
# Set Link 45 geometry to [1.2876667490722287, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0883316033409194 for 46 in 46
# Updated Geom2 value to 0.0 for 46 in 46
# Updated Geom3 value to 0.0 for 46 in 46
# Updated Geom4 value to 0.0 for 46 in 46
# Set Link 46 geometry to [1.0883316033409194, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.4843283673011314 for 47 in 47
# Updated Geom2 value to 0.0 for 47 in 47
# Updated Geom3 value to 0.0 for 47 in 47
# Updated Geom4 value to 0.0 for 47 in 47
# Set Link 47 geometry to [1.4843283673011314, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.106597615299021 for 48 in 48
# Updated Geom2 value to 0.0 for 48 in 48
# Updated Geom3 value to 0.0 for 48 in 48
# Updated Geom4 value to 0.0 for 48 in 48
# Set Link 48 geometry to [1.106597615299021, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1412092683143207 for 49 in 49
# Updated Geom2 value to 0.0 for 49 in 49
# Updated Geom3 value to 0.0 for 49 in 49
# Updated Geom4 value to 0.0 for 49 in 49
# Set Link 49 geometry to [1.1412092683143207, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.359675734882031 for 50 in 50
# Updated Geom2 value to 0.0 for 50 in 50
# Updated Geom3 value to 0.0 for 50 in 50
# Updated Geom4 value to 0.0 for 50 in 50
# Set Link 50 geometry to [1.359675734882031, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1787961346983566 for 51 in 51
# Updated Geom2 value to 0.0 for 51 in 51
# Updated Geom3 value to 0.0 for 51 in 51
# Updated Geom4 value to 0.0 for 51 in 51
# Set Link 51 geometry to [1.1787961346983566, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1227446404217323 for 52 in 52
# Updated Geom2 value to 0.0 for 52 in 52
# Updated Geom3 value to 0.0 for 52 in 52
# Updated Geom4 value to 0.0 for 52 in 52
# Set Link 52 geometry to [1.1227446404217323, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.3608129610176478 for 53 in 53
# Updated Geom2 value to 0.0 for 53 in 53
# Updated Geom3 value to 0.0 for 53 in 53
# Updated Geom4 value to 0.0 for 53 in 53
# Set Link 53 geometry to [1.3608129610176478, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.2168338339654519 for 54 in 54
# Updated Geom2 value to 0.0 for 54 in 54
# Updated Geom3 value to 0.0 for 54 in 54
# Updated Geom4 value to 0.0 for 54 in 54
# Set Link 54 geometry to [1.2168338339654519, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.0199042925898232 for 55 in 55
# Updated Geom2 value to 0.0 for 55 in 55
# Updated Geom3 value to 0.0 for 55 in 55
# Updated Geom4 value to 0.0 for 55 in 55
# Set Link 55 geometry to [1.0199042925898232, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.3717629094834034 for 56 in 56
# Updated Geom2 value to 0.0 for 56 in 56
# Updated Geom3 value to 0.0 for 56 in 56
# Updated Geom4 value to 0.0 for 56 in 56
# Set Link 56 geometry to [1.3717629094834034, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.2636119578780205 for 57 in 57
# Updated Geom2 value to 0.0 for 57 in 57
# Updated Geom3 value to 0.0 for 57 in 57
# Updated Geom4 value to 0.0 for 57 in 57
# Set Link 57 geometry to [1.2636119578780205, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.2590658674359803 for 58 in 58
# Updated Geom2 value to 0.0 for 58 in 58
# Updated Geom3 value to 0.0 for 58 in 58
# Updated Geom4 value to 0.0 for 58 in 58
# Set Link 58 geometry to [1.2590658674359803, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1932831930001826 for 59 in 59
# Updated Geom2 value to 0.0 for 59 in 59
# Updated Geom3 value to 0.0 for 59 in 59
# Updated Geom4 value to 0.0 for 59 in 59
# Set Link 59 geometry to [1.1932831930001826, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.1919618450843479 for 60 in 60
# Updated Geom2 value to 0.0 for 60 in 60
# Updated Geom3 value to 0.0 for 60 in 60
# Updated Geom4 value to 0.0 for 60 in 60
# Set Link 60 geometry to [1.1919618450843479, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.4343603972408696 for 61 in 61
# Updated Geom2 value to 0.0 for 61 in 61
# Updated Geom3 value to 0.0 for 61 in 61
# Updated Geom4 value to 0.0 for 61 in 61
# Set Link 61 geometry to [1.4343603972408696, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.4591517146548219 for 62 in 62
# Updated Geom2 value to 0.0 for 62 in 62
# Updated Geom3 value to 0.0 for 62 in 62
# Updated Geom4 value to 0.0 for 62 in 62
# Set Link 62 geometry to [1.4591517146548219, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.4819458516778155 for 63 in 63
# Updated Geom2 value to 0.0 for 63 in 63
# Updated Geom3 value to 0.0 for 63 in 63
# Updated Geom4 value to 0.0 for 63 in 63
# Set Link 63 geometry to [1.4819458516778155, 0.0, 0.0, 0.0]
# Updated Geom1 value to 1.179713149329444 for 65 in 65
# Updated Geom2 value to 0.0 for 65 in 65
# Updated Geom3 value to 0.0 for 65 in 65
# Updated Geom4 value to 0.0 for 65 in 65
# Set Link 65 geometry to [1.179713149329444, 0.0, 0.0, 0.0]

# %% [markdown]
# ### Add uncertainty to conduit roughness.

# %%
# Add uncertainty to conduit geometries.
roughness_bounds = (0.005, 0.02)

for conduit_name in conduit_names:
    # Alter roughness with randomized value.
    new_roughness = np.random.uniform(roughness_bounds[0], roughness_bounds[1])
    
    # Get link roughness.
    swmm.set_link_roughness(conduit_name, new_roughness)
# Out:
# Updated Roughness value to 0.013703225603267876 for 20 in 20
# Set Link 20 roughness to 0.013703225603267876
# Updated Roughness value to 0.0147019918146627 for 21 in 21
# Set Link 21 roughness to 0.0147019918146627
# Updated Roughness value to 0.010228527603728207 for 22 in 22
# Set Link 22 roughness to 0.010228527603728207
# Updated Roughness value to 0.012625329833927619 for 23 in 23
# Set Link 23 roughness to 0.012625329833927619
# Updated Roughness value to 0.012710013338745104 for 24 in 24
# Set Link 24 roughness to 0.012710013338745104
# Updated Roughness value to 0.011311540764593788 for 25 in 25
# Set Link 25 roughness to 0.011311540764593788
# Updated Roughness value to 0.009643031799971016 for 26 in 26
# Set Link 26 roughness to 0.009643031799971016
# Updated Roughness value to 0.01964274084099733 for 27 in 27
# Set Link 27 roughness to 0.01964274084099733
# Updated Roughness value to 0.007345738503475789 for 28 in 28
# Set Link 28 roughness to 0.007345738503475789
# Updated Roughness value to 0.00698893916419459 for 29 in 29
# Set Link 29 roughness to 0.00698893916419459
# Updated Roughness value to 0.018954742665649487 for 33 in 33
# Set Link 33 roughness to 0.018954742665649487
# Updated Roughness value to 0.0167590512331879 for 34 in 34
# Set Link 34 roughness to 0.0167590512331879
# Updated Roughness value to 0.01671668449657713 for 37 in 37
# Set Link 37 roughness to 0.01671668449657713
# Updated Roughness value to 0.011230746121173375 for 38 in 38
# Set Link 38 roughness to 0.011230746121173375
# Updated Roughness value to 0.013177619668249749 for 39 in 39
# Set Link 39 roughness to 0.013177619668249749
# Updated Roughness value to 0.012872978661609608 for 40 in 40
# Set Link 40 roughness to 0.012872978661609608
# Updated Roughness value to 0.01886971815898549 for 41 in 41
# Set Link 41 roughness to 0.01886971815898549
# Updated Roughness value to 0.007492994150602391 for 42 in 42
# Set Link 42 roughness to 0.007492994150602391
# Updated Roughness value to 0.01772057922080741 for 43 in 43
# Set Link 43 roughness to 0.01772057922080741
# Updated Roughness value to 0.01980310178592209 for 44 in 44
# Set Link 44 roughness to 0.01980310178592209
# Updated Roughness value to 0.019315269368370608 for 45 in 45
# Set Link 45 roughness to 0.019315269368370608
# Updated Roughness value to 0.01933170212429468 for 46 in 46
# Set Link 46 roughness to 0.01933170212429468
# Updated Roughness value to 0.017090233720038706 for 47 in 47
# Set Link 47 roughness to 0.017090233720038706
# Updated Roughness value to 0.009468285936971164 for 48 in 48
# Set Link 48 roughness to 0.009468285936971164
# Updated Roughness value to 0.011810418038124805 for 49 in 49
# Set Link 49 roughness to 0.011810418038124805
# Updated Roughness value to 0.0056767416605923065 for 50 in 50
# Set Link 50 roughness to 0.0056767416605923065
# Updated Roughness value to 0.017174652628951945 for 51 in 51
# Set Link 51 roughness to 0.017174652628951945
# Updated Roughness value to 0.010926922509870048 for 52 in 52
# Set Link 52 roughness to 0.010926922509870048
# Updated Roughness value to 0.018001296814112704 for 53 in 53
# Set Link 53 roughness to 0.018001296814112704
# Updated Roughness value to 0.007889750423920677 for 54 in 54
# Set Link 54 roughness to 0.007889750423920677
# Updated Roughness value to 0.01365834193207588 for 55 in 55
# Set Link 55 roughness to 0.01365834193207588
# Updated Roughness value to 0.013166512223954055 for 56 in 56
# Set Link 56 roughness to 0.013166512223954055
# Updated Roughness value to 0.007488614166562603 for 57 in 57
# Set Link 57 roughness to 0.007488614166562603
# Updated Roughness value to 0.014269648371930527 for 58 in 58
# Set Link 58 roughness to 0.014269648371930527
# Updated Roughness value to 0.005404322919351041 for 59 in 59
# Set Link 59 roughness to 0.005404322919351041
# Updated Roughness value to 0.00626139322364516 for 60 in 60
# Set Link 60 roughness to 0.00626139322364516
# Updated Roughness value to 0.005828151567155579 for 61 in 61
# Set Link 61 roughness to 0.005828151567155579
# Updated Roughness value to 0.017464661391670418 for 62 in 62
# Set Link 62 roughness to 0.017464661391670418
# Updated Roughness value to 0.010409951073775393 for 63 in 63
# Set Link 63 roughness to 0.010409951073775393
# Updated Roughness value to 0.015608997914957314 for 65 in 65
# Set Link 65 roughness to 0.015608997914957314
